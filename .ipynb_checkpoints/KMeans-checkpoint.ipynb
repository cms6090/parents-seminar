# %%
file_path = "C:\\Users\\cho03\\Downloads\\세미나\\방학 세미나\\"

# %%
import itertools # 반복 객체를 유용하게 다루는 라이브러리
import re  # 정규표현식을 사용할 수 있는 라이브러리
from sklearn.feature_extraction.text import TfidfVectorizer  # tf-idf값을 구하기 위해서 사용
from collections import defaultdict
from collections import Counter   # 단어들을 쉽게 집계하는 라이브러리
from wordcloud import WordCloud
import matplotlib
import matplotlib.pyplot as plt   # 시각화하는 라이브러리
from IPython.display import set_matplotlib_formats
from gensim import corpora, models
set_matplotlib_formats('retina')   # 선명하게 시각화
font_path = file_path + 'font\\Nanum_Gothic\\NanumGothic-Bold.ttf' 
from sklearn.cluster import KMeans
from tqdm import tqdm_notebook # progress bar
from tqdm import tqdm # 진행률 피드백 라이브러리
from matplotlib import rc, font_manager
import seaborn as sns
rc('font', family='Malgun Gothic')
import pickle
import pandas as pd
# Out:
# C:\Users\cho03\AppData\Local\Temp\ipykernel_30696\2925494364.py:11: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   set_matplotlib_formats('retina')   # 선명하게 시각화

# %%
f = open(file_path + 'total_doc.pkl', "rb") # 데이터 불러오기
data = pickle.load(f)
f.close()
data
# Out:
#                                            title
# 0                       급여노인장기요양인정신청아들보다딸이부양하는시대  \
# 1                                   한국년노인부양부담세계위
# 2                                         여성노인부양
# 3                                   세이상노인부양가정이라면
# 4                                    가족관계변화와노인부양
# ...                                          ...
# 2159                      노인은무엇으로사는가감사의마음으로사는것이다
# 2160                             한장으로보는우리나라가망한이유
# 2161                      세이상노인혜택가지몰라서못쓰는사람이더많아탄
# 2162  청주주간보호청주요양원추천방영된프로그램전문기관재활운동요양등급상담노인주간보호센터
# 2163                         노인장기요양보험체험수기및사진공모안내
#
#                                                     doc like comment_cnt
# 0     저출산과맞물려우리가생각해봐야할것이다저출산은국가성장의미래문제만으로국한지어생각할수없다초...    5              \
# 1     통계청세계한국인구전망급속한저출산고령화직격탄한국인구프로감소만명세계인구는프로증가억명고령...   50           2
# 2     부양제판노인복지론부양의양과종류는가족이가진경제적자원가족구조부양자피부양자간관계의질가족에...    4
# 3     세이상노인부양가정이라면안녕하세요저희는어르신들의남은여생을더욱풍요롭고안락하게만들어드리기...    3           1
# ...

# %%
doc_noun = []
for i in range(0,len(data['doc_token_noun'])):
    doc_noun.append(' '.join(data['doc_token_noun'][i]))  # 각 문서의 명사들을 str으로 연결     #['문서1 명사', '문서2 명사', '...']

# %%
# 텍스트 문서 모음을 단어 tf-idf 행렬로 변환 
vec = TfidfVectorizer(min_df = 0.01, max_df=0.95) # 문서의 1%~95%로 나타나는 단어만 고려.  #min_df: 특정 단어가 나타나는 '문서의 수의 최소 빈도값을 설정/소수형태면 %로 설정
X = vec.fit_transform(doc_noun) # 설정한 Vectorizer로 벡터화

# %%
print(vec.get_feature_names())  # 단어 가나다 순 인덱스
# Out:
# ['가가', '가계', '가구', '가구원', '가나', '가난', '가노', '가능', '가대', '가로', '가발', '가부', '가사', '가세', '가속', '가액', '가에', '가우리', '가운데', '가의', '가이', '가입', '가입자', '가자', '가장', '가정', '가제', '가중', '가지', '가치', '가치관', '각성', '간의', '간호', '간호사', '갈등', '감각', '감당', '감동', '감사', '감안', '감정', '강제', '강조', '강화', '개발', '개월', '개인', '개입', '거리', '거부', '거주', '거주지', '걱정', '건강', '건강관리', '건강보험', '건강증진', '건지', '검색', '검토', '게시', '겨자', '격려', '결론', '결정', '결혼', '경감', '경기', '경기도', '경로', '경색', '경제성장', '경향', '경험', '계가', '계산', '계속', '계약', '계절', '계층', '계획', '고가', '고갈', '고노', '고독', '고려', '고령자', '고령화사회', '고립', '고민', '고사', '고수', '고용', '고의', '고통', '곤란', '공간', '공감', '공공', '공급', '공단', '공동', '공동생활', '공동체', '공무원', '공부', '공식', '공유', '공적', '공제', '과거', '과목', '과정', '과편', '관계', '관련', '관리', '관심', '관점', '광고', '광역', '교사', '교수', '교육', '교육원', '구가', '구독', '구로', '구명', '구분', '구성', '구성원', '구원', '구의', '구조', '구청', '구체', '구축', '국내', '국민건강보험', '국민건강보험공단', '국민연금', '국의', '국제', '군구', '권리', '권리금', '규모', '규정', '그동안', '그룹', '극복', '근거', '근로', '근로자', '근심', '글쓰기', '글자', '
# ...

# %%
print(X)  # (문서인덱스, 등장단어인덱스) tf-idf값
# Out:
#   (1, 1163)	0.0938511812126023
#   (1, 626)	0.08275181213616582
#   (1, 712)	0.12293369516343014
#   (1, 79)	0.1195927652966333
#   (1, 106)	0.11601222378797509
#   (1, 838)	0.11601222378797509
#   (1, 207)	0.1017741599485016
#   (1, 301)	0.11601222378797509
#   (1, 231)	0.09041661926891965
#   (1, 329)	0.09538654687637518
#   (1, 257)	0.11882964238450443
#   (1, 186)	0.09288286116367711
#   (1, 45)	0.11125566242284124
#   (1, 117)	0.08399405669654904
#   (1, 713)	0.08781256691471202
#   (1, 54)	0.13890741606891285
#   (1, 458)	0.20955989518860543
#   (1, 575)	0.11668421309372722
#   (1, 560)	0.08059265306757461
#   (1, 402)	0.07220984465517993
#   (1, 640)	0.07418567102534893
#   (1, 978)	0.08706836789611315
#   (1, 86)	0.09062998551124136
#   (1, 555)	0.1808332385378393
#   (1, 203)	0.08275181213616582
#   :	:
#   (2163, 390)	0.12285799380450703
#   (2163, 471)	0.13815363865711539
#   (2163, 167)	0.04710991070243658
#   (2163, 168)	0.07841992300078371
# ...

# %%
# 군집수가 1~9개일때로 elbow 그래프 시각화
def elbow(X):
    sse = []

    for i in range(1,10):
        km = KMeans(n_clusters=i, algorithm='auto', random_state=1)  #k-means algorithm: auto(기본값))
        km.fit(X) # k-means clustering
        sse.append(km.inertia_)
        print(i)
        
    plt.plot(range(1,10), sse, marker='o')
    plt.xlabel('K')
    plt.ylabel('SSE')
    plt.xticks(range(1,10))
    plt.show()

elbow(X)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [9], in <cell line: 17>()
#      14     plt.xticks(range(1,10))
#      15     plt.show()
# ---> 17 elbow(X)
#
# Input In [9], in elbow(X)
#       5 for i in range(1,10):
#       6     km = KMeans(n_clusters=i, algorithm='auto', random_state=1)  #k-means algorithm: auto(기본값))
# ----> 7     km.fit(X) # k-means clustering
#       8     sse.append(km.inertia_)
#       9     print(i)
#
# File ~\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1186, in KMeans.fit(self, X, y, sample_weight)
#    1183     print("Initialization complete")
#    1185 # run a k-means once
# -> 1186 labels, inertia, centers, n_iter_ = kmeans_single(
#    1187     X,
#    1188     sample_weight,
#    1189     centers_init,
#    1190     max_iter=self.max_iter,
#    1191     verbose=self.verbose,
#    1192     tol=self._tol,
# ...

# %%
# 최적의 클러스터 수(2)로 k-means 실행
from sklearn.cluster import KMeans
model = KMeans(n_clusters=2, algorithm='auto', random_state=0)
model.fit(X)

# %%
print("Top terms per cluster:")
order_centroids = model.cluster_centers_.argsort()[:, ::-1]   
terms = vec.get_feature_names()  # 벡터에 해당하는 단어
for i in range(2):
    print("Cluster %d:" % i)
    for ind in order_centroids[i, :30]:   # [행, 열]     # [클러스터 인덱스, 클러스터 내 인덱스]
        print(' %s' % terms[ind])   # ind: 가져온 단어 인덱스    #terms[ind]: 해당 인덱스를 가진 단어
    print('\n')

# %%
cluster0_list = []
cluster1_list = []

for i in range(2):
    cluster_terms = []
    for ind in order_centroids[i, :30]:
        cluster_terms.append(terms[ind])
    if i == 0:
        cluster0_list = cluster_terms
    elif i == 1:
        cluster1_list = cluster_terms

# %%
cluster0_list

# %%
cluster1_list

# %% [markdown]
# ## 토픽별 워드 클라우드

# %%
text = ' '.join(cluster0_list)

# 텍스트 데이터로 워드 클라우드 생성
wordcloud = WordCloud(font_path=file_path + 'NanumGothic.ttf', background_color='white', colormap="Accent", width=600, height=400).generate(text)

# 워드 클라우드 그리기
plt.figure(figsize=(12, 8))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
text = ' '.join(cluster1_list)

# 텍스트 데이터로 워드 클라우드 생성
wordcloud = WordCloud(font_path=file_path + 'NanumGothic.ttf', background_color='white', colormap="Accent", width=600, height=400).generate(text)

# 워드 클라우드 그리기
plt.figure(figsize=(12, 8))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
