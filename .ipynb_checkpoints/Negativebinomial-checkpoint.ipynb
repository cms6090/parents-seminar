# %% [markdown]
# ## Hypothesis Testing : GLM

# %%
import pandas as pd
import numpy as np
import pickle

from patsy import dmatrices

import statsmodels.api as sm
from statsmodels.formula.api import glm

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score   # In linear regression model, R-squares (결정계수)
from math import sqrt

# %%
file_path = 'C:\\Users\\cho03\\Downloads\\세미나\\방학 세미나\\' # data가 저장된 파일 경로

# %%
# 불러오기
f = open(file_path + "total_docs1.pkl", "rb")
data1 = pickle.load(f)
f.close()

# %%
# 불러오기
f = open(file_path + "total_docs2.pkl", "rb")
data2 = pickle.load(f)
f.close()

# %%
data = pd.DataFrame(dtype='int64')
data['title'] = data1['title']
data['doc'] = data1['doc']
data['ch1'] = data1['ch']
data['ch2'] = data1['ch2']
data['like'] = data1['like']
data['img_cnt'] = data1['img']
data['div_cnt'] = data1['div']
data['score1'] = data1['score']
data
# Out:
#                                                   title
# 0                          급여노인장기요양인정신청 아들보다 딸이 부양하는 시대  \
# 1                                 한국 2070년 노인부양 부담 세계1위
# 2                                               여성노인 부양
# 3                                     65세 이상 노인 부양가정이라면
# 4                                        가족관계 변화와 노인 부양
# ...                                                 ...
# 2162                      노인은 무엇으로 사는가  감사의 마음으로 사는 것이다
# 2163                            한 장으로 보는 우리나라가 망한 이유jpg
# 2164              65세 이상 노인 혜택 50가지 몰라서 못 쓰는 사람이 더 많아1탄
# 2165  청주주간보호 청주요양원 추천 kbs방영된 프로그램전문기관 재활운동 요양등급상담 99...
# 2166                           노인장기요양보험 체험수기 및 사진 공모 안내
#
#                                                     doc    ch1   ch2  like
# 0     저출산과 맞물려 우리가 생각해봐야 할 것이다저출산은 국가 성장의 미래  문제만으로 ...  naver  blog     5  \
# 1      통계청 세계  한국 인구전망급속한 저출산 고령화 직격탄한국 인구 27프로 감소 3...  naver  blog    50
# 2       부양제2판 노인복지론 2002 p284부양의 양과 종류는 가족이 가진 경제적 자...  naver  blog     4
# 3     65세 이상 노인 부양가정이라면안녕하세요저희는 어르신들의 남은 여생을 더욱 풍요롭고...  naver  blog     3
# 4     가족관계 변화와 노인 부양노인 거주 형태의 변화  혼자 살거나 노부부만 사는 세대가...  naver  blog     2
# ...                                                 ...    ...   ...   ...
# 2162  노인은 무엇으로 사는가  감사의 마음으로 사는 것이다이런 질문부터 시작 해 보자 당...   daum  cafe     3
# 2163  출처대한민국 통계청인류 역사상 유래 없는 현상곧우리나라인구의40가65세이상노인으로구...   daum  cafe     3
# 2164  65세 이상 노인 혜택 50가지 몰라서 못 쓰는 사람이 더 많아1탄by M가이드현재...   daum  cafe     0
# 2165  KBS방영된 프로그램전문기관 9988 청주노인주간보호센터입니다 33명 정원의 아늑한...   daum  cafe     0
# 2166  장기요양 서비스 우수사례를 발굴하여 국민의 공감대 형성과 관심도제고를 위하여2023...   daum  cafe     0
#
#       img_cnt  div_cnt    score1
# 0           2        0 -0.234043
# 1           2        0 -0.153846
# 2           4        0 -0.533333
# 3          12        1  0.533333
# 4           1        0  0.160000
# ...       ...      ...       ...
# 2162        4        0  0.966102
# 2163        2        0  0.000000
# 2164        6        0  0.050000
# 2165       26        2  1.052632
# 2166        0        0  0.500000
#
# [2167 rows x 8 columns]

# %%
#filename : 모든 전처리과정 완료 및 감성 스코어 등이 모두 포함된 dataset,
# Ex : title, doc, ch1, ch2, engagement(좋아요수), only_text_doc(0,1), image_count, photo_count, 감성(score1), Emolex감성(score2) 등

# %%
data = data[data['img_cnt'] != '<NA>']
data = data[data['like'] != '<NA>']
data = data[data['div_cnt'] != '<NA>']

data = data.reset_index(drop=True)
data
# Out:
#                                                   title
# 0                          급여노인장기요양인정신청 아들보다 딸이 부양하는 시대  \
# 1                                 한국 2070년 노인부양 부담 세계1위
# 2                                               여성노인 부양
# 3                                     65세 이상 노인 부양가정이라면
# 4                                        가족관계 변화와 노인 부양
# ...                                                 ...
# 1949                      노인은 무엇으로 사는가  감사의 마음으로 사는 것이다
# 1950                            한 장으로 보는 우리나라가 망한 이유jpg
# 1951              65세 이상 노인 혜택 50가지 몰라서 못 쓰는 사람이 더 많아1탄
# 1952  청주주간보호 청주요양원 추천 kbs방영된 프로그램전문기관 재활운동 요양등급상담 99...
# 1953                           노인장기요양보험 체험수기 및 사진 공모 안내
#
#                                                     doc    ch1   ch2  like
# 0     저출산과 맞물려 우리가 생각해봐야 할 것이다저출산은 국가 성장의 미래  문제만으로 ...  naver  blog     5  \
# 1      통계청 세계  한국 인구전망급속한 저출산 고령화 직격탄한국 인구 27프로 감소 3...  naver  blog    50
# 2       부양제2판 노인복지론 2002 p284부양의 양과 종류는 가족이 가진 경제적 자...  naver  blog     4
# 3     65세 이상 노인 부양가정이라면안녕하세요저희는 어르신들의 남은 여생을 더욱 풍요롭고...  naver  blog     3
# 4     가족관계 변화와 노인 부양노인 거주 형태의 변화  혼자 살거나 노부부만 사는 세대가...  naver  blog     2
# ...                                                 ...    ...   ...   ...
# 1949  노인은 무엇으로 사는가  감사의 마음으로 사는 것이다이런 질문부터 시작 해 보자 당...   daum  cafe     3
# 1950  출처대한민국 통계청인류 역사상 유래 없는 현상곧우리나라인구의40가65세이상노인으로구...   daum  cafe     3
# 1951  65세 이상 노인 혜택 50가지 몰라서 못 쓰는 사람이 더 많아1탄by M가이드현재...   daum  cafe     0
# 1952  KBS방영된 프로그램전문기관 9988 청주노인주간보호센터입니다 33명 정원의 아늑한...   daum  cafe     0
# 1953  장기요양 서비스 우수사례를 발굴하여 국민의 공감대 형성과 관심도제고를 위하여2023...   daum  cafe     0
#
#       img_cnt  div_cnt    score1
# 0           2        0 -0.234043
# 1           2        0 -0.153846
# 2           4        0 -0.533333
# 3          12        1  0.533333
# 4           1        0  0.160000
# ...       ...      ...       ...
# 1949        4        0  0.966102
# 1950        2        0  0.000000
# 1951        6        0  0.050000
# 1952       26        2  1.052632
# 1953        0        0  0.500000
#
# [1954 rows x 8 columns]

# %% [markdown]
# ## Splitting to test and train sets

# %%
mask = np.random.rand(len(data)) < 0.7   # 70%를 train dataset 으로 사용
data_train=data[mask]
data_test=data[~mask]

# %%
data_train
# Out:
#                                             title
# 0                    급여노인장기요양인정신청 아들보다 딸이 부양하는 시대  \
# 1                           한국 2070년 노인부양 부담 세계1위
# 3                               65세 이상 노인 부양가정이라면
# 4                                  가족관계 변화와 노인 부양
# 5               치매노인의 실태 치매노인의 임상적 특성 치매노인 부양의 결과
# ...                                           ...
# 1947                노인은 무엇으로 사는가  감사의 마음으로 사는 것이다
# 1948  청주주간보호 청주요양원 9988노인주간보호 어르신 건강증진인지활동 프로그램소개
# 1949                노인은 무엇으로 사는가  감사의 마음으로 사는 것이다
# 1950                      한 장으로 보는 우리나라가 망한 이유jpg
# 1953                     노인장기요양보험 체험수기 및 사진 공모 안내
#
#                                                     doc    ch1   ch2  like
# 0     저출산과 맞물려 우리가 생각해봐야 할 것이다저출산은 국가 성장의 미래  문제만으로 ...  naver  blog     5  \
# 1      통계청 세계  한국 인구전망급속한 저출산 고령화 직격탄한국 인구 27프로 감소 3...  naver  blog    50
# 3     65세 이상 노인 부양가정이라면안녕하세요저희는 어르신들의 남은 여생을 더욱 풍요롭고...  naver  blog     3
# 4     가족관계 변화와 노인 부양노인 거주 형태의 변화  혼자 살거나 노부부만 사는 세대가...  naver  blog     2
# 5     치매노인가족1치매의 개념과 치매노인의 실태개념과 유형 개념치매는 다방면의 인지기능 ...  naver  blog     3
# ...                                                 ...    ...   ...   ...
# 1947  노인은 무엇으로 사는가  감사의 마음으로 사는 것이다이런 질문부터 시작 해 보자 당...   daum  cafe     0
# 1948  KBS방영된 프로그램전문기관 9988 청주노인주간보호센터입니다 33명 정원의 아늑한...   daum  cafe     0
# 1949  노인은 무엇으로 사는가  감사의 마음으로 사는 것이다이런 질문부터 시작 해 보자 당...   daum  cafe     3
# 1950  출처대한민국 통계청인류 역사상 유래 없는 현상곧우리나라인구의40가65세이상노인으로구...   daum  cafe     3
# 1953  장기요양 서비스 우수사례를 발굴하여 국민의 공감대 형성과 관심도제고를 위하여2023...   daum  cafe     0
#
#       img_cnt  div_cnt    score1
# 0           2        0 -0.234043
# 1           2        0 -0.153846
# 3          12        1  0.533333
# 4           1        0  0.160000
# 5           0        0 -0.857143
# ...       ...      ...       ...
# 1947        4        0  0.966102
# 1948       36        2  1.052632
# 1949        4        0  0.966102
# 1950        2        0  0.000000
# 1953        0        0  0.500000
#
# [1337 rows x 8 columns]

# %%
data_test
# Out:
#                                                   title
# 2                                               여성노인 부양  \
# 7                                   연경요양병원 가족관계변화와 노인부양
# 13                             노인 대상자 어르신 거주지 요양보호부양 방안
# 14                      노인빈곤율 세계 1등 초고령사회 단 2년 남았다 부모부양
# 15                                죽음을 기다리는 노인 부양을 위한 비용
# ...                                                 ...
# 1937  청주주간보호 청주요양원 추천 kbs방영된 프로그램전문기관 재활운동 요양등급상담 99...
# 1943                      노인은 무엇으로 사는가  감사의 마음으로 사는 것이다
# 1945                      노인은 무엇으로 사는가  감사의 마음으로 사는 것이다
# 1951              65세 이상 노인 혜택 50가지 몰라서 못 쓰는 사람이 더 많아1탄
# 1952  청주주간보호 청주요양원 추천 kbs방영된 프로그램전문기관 재활운동 요양등급상담 99...
#
#                                                     doc    ch1   ch2  like
# 2       부양제2판 노인복지론 2002 p284부양의 양과 종류는 가족이 가진 경제적 자...  naver  blog     4  \
# 7     연경요양병원 가족관계변화와노인부양1 연경요양병원   1 연경요양병원을 소개합니다 연...  naver  blog    57
# 13    안녕하세요 신뢰할 수 있는 기업가온재가 복지센터 입니다노인성 질병을 가지고 계신분의...  naver  blog     1
# 14     우리나라의 고령화속도는 전세계 어느 나라도 따라올 수 없는 상태에 이르렀습니다통계...  naver  blog     4
# 15    안녕하세요 수발TV 이영우 센터장입니다 제가 항상 강조하는 것 중의 하나가 부모님 ...  naver  blog    26
# ...                                                 ...    ...   ...   ...
# 1937  KBS방영된 프로그램전문기관 9988 청주노인주간보호센터입니다 33명 정원의 아늑한...   daum  cafe     0
# 1943  노인은 무엇으로 사는가  감사의 마음으로 사는 것이다이런 질문부터 시작 해 보자 당...   daum  cafe     0
# 1945  노인은 무엇으로 사는가  감사의 마음으로 사는 것이다이런 질문부터 시작 해 보자 당...   daum  cafe     0
# 1951  65세 이상 노인 혜택 50가지 몰라서 못 쓰는 사람이 더 많아1탄by M가이드현재...   daum  cafe     0
# 1952  KBS방영된 프로그램전문기관 9988 청주노인주간보호센터입니다 33명 정원의 아늑한...   daum  cafe     0
#
#       img_cnt  div_cnt    score1
# 2           4        0 -0.533333
# 7           1        0  0.318182
# 13          5        0  0.259259
# 14         23        0 -0.200000
# 15          4        0  0.200000
# ...       ...      ...       ...
# 1937       26        2  1.052632
# 1943        4        0  0.966102
# 1945        4        0  0.966102
# 1951        6        0  0.050000
# 1952       26        2  1.052632
#
# [617 rows x 8 columns]

# %%
data_train['like'] = data_train['like'].astype('int64')
data_train['img_cnt'] = data_train['img_cnt'].astype('int64')
data_train['div_cnt'] = data_train['div_cnt'].astype('int64')

data_test['like'] = data_test['like'].astype('int64')
data_test['img_cnt'] = data_test['img_cnt'].astype('int64')
data_test['div_cnt'] = data_test['div_cnt'].astype('int64')
# Out:
# C:\Users\cho03\AppData\Local\Temp\ipykernel_11888\3311031113.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_train['like'] = data_train['like'].astype('int64')
# C:\Users\cho03\AppData\Local\Temp\ipykernel_11888\3311031113.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_train['img_cnt'] = data_train['img_cnt'].astype('int64')
# C:\Users\cho03\AppData\Local\Temp\ipykernel_11888\3311031113.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_train['div_cnt'] = data_train['div_cnt'].astype('int64')
# C:\Users\cho03\AppData\Local\Temp\ipykernel_11888\3311031113.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_test['like'] = data_test['like'].astype('int64')
# C:\Users\cho03\AppData\Local\Temp\ipykernel_11888\3311031113.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_test['img_cnt'] = data_test['img_cnt'].astype('int64')
# C:\Users\cho03\AppData\Local\Temp\ipykernel_11888\3311031113.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_test['div_cnt'] = data_test['div_cnt'].astype('int64')

# %%
expr ="""like ~ img_cnt + div_cnt + score1"""

# %%
y_train, X_train = dmatrices(expr, data_train, return_type='dataframe')
y_test, X_test = dmatrices(expr, data_test, return_type='dataframe')

# %% [markdown]
# ## Negativebinomial model (음이항 모델)

# %%
nb_training_results = sm.GLM(y_train, X_train, family=sm.families.NegativeBinomial(alpha = 1)).fit()

# %%
print(nb_training_results.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                   like   No. Observations:                 1337
# Model:                            GLM   Df Residuals:                     1333
# Model Family:        NegativeBinomial   Df Model:                            3
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -4043.1
# Date:                Sun, 23 Jul 2023   Deviance:                       3915.2
# Time:                        22:55:22   Pearson chi2:                 1.19e+04
# No. Iterations:                    48   Pseudo R-squ. (CS):             0.1168
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.6880      0.032     52.305      0.000       1.625       1.751
# img_cnt        0.0734      0.004     20.798      0.000       0.067       0.080
# div_cnt        0.1789      0.086      2.083      0.037       0.011       0.347
# score1        -0.2422      0.045     -5.332      0.000      -0.331      -0.153
# ==============================================================================

# %%
nb_prediction_train= nb_training_results.get_prediction(X_train)
nb_summary_frame_train= nb_prediction_train.summary_frame()
print(nb_summary_frame_train)
# Out:
#            mean    mean_se  mean_ci_lower  mean_ci_upper
# 0      6.629430   0.204215       6.241020       7.042014
# 1      6.501884   0.196669       6.127624       6.899003
# 3     13.718482   1.203908      11.550646      16.293181
# 4      5.599312   0.184905       5.248384       5.973704
# 5      6.656644   0.309335       6.077149       7.291397
# ...         ...        ...            ...            ...
# 1947   5.741030   0.320284       5.146388       6.404380
# 1948  84.265321  15.682096      58.510936     121.355849
# 1949   5.741030   0.320284       5.146388       6.404380
# 1950   6.264033   0.190420       5.901717       6.648592
# 1953   4.791579   0.202714       4.410292       5.205829
#
# [1337 rows x 4 columns]

# %%
predicted_counts_train = nb_summary_frame_train['mean']
predicted_counts_train
# Out:
# 0        6.629430
# 1        6.501884
# 3       13.718482
# 4        5.599312
# 5        6.656644
#           ...
# 1947     5.741030
# 1948    84.265321
# 1949     5.741030
# 1950     6.264033
# 1953     4.791579
# Name: mean, Length: 1337, dtype: float64

# %%
r2_score(y_train, predicted_counts_train)
# Out:
# -1606.0308985006006

# %%
nb_prediction_test = nb_training_results.get_prediction(X_test)
nb_summary_frame_test= nb_prediction_test.summary_frame()
print(nb_summary_frame_test)
# Out:
#            mean   mean_se  mean_ci_lower  mean_ci_upper
# 2      8.255364  0.302103       7.683989       8.869226
# 7      5.388816  0.195280       5.019349       5.785478
# 13     7.332282  0.247279       6.863294       7.833316
# 14    30.726714  2.360617      26.431482      35.719939
# 15     6.911729  0.223630       6.487031       7.364232
# ...         ...       ...            ...            ...
# 1937  40.437247  7.076190      28.696454      56.981639
# 1943   5.741030  0.320284       5.146388       6.404380
# 1945   5.741030  0.320284       5.146388       6.404380
# 1951   8.301197  0.262991       7.801421       8.832991
# 1952  40.437247  7.076190      28.696454      56.981639
#
# [617 rows x 4 columns]

# %%
predicted_counts_test = nb_summary_frame_test['mean']
predicted_counts_test
# Out:
# 2        8.255364
# 7        5.388816
# 13       7.332282
# 14      30.726714
# 15       6.911729
#           ...
# 1937    40.437247
# 1943     5.741030
# 1945     5.741030
# 1951     8.301197
# 1952    40.437247
# Name: mean, Length: 617, dtype: float64

# %%
x_index_array = np.array(X_test.index)
predicted_counts_array = np.array(predicted_counts_test)

# %%
plt.plot(x_index_array, predicted_counts_array, 'go-', label='Predicted counts')

# %%
r2_score(y_test, predicted_counts_test)
# Out:
# -0.07006412275255514

# %%
fig=plt.figure(figsize=(12,8))
fig.suptitle('Predicted versus actual patent counts')

x_index_array = np.array(X_test.index)
predicted_counts_array = np.array(predicted_counts_test)

predicted, = plt.plot(x_index_array, predicted_counts_array, 'go-', label='Predicted counts')

y_test_array = np.array(y_test)

actual, = plt.plot(x_index_array, y_test_array,  'ro-', label='Actual counts')

plt.legend(handles=[predicted, actual])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
